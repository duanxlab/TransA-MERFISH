# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
from ClusterMap.clustermap import *
#now this ipynb should be in the ClusterMap folder, so that the module is imported correctly. 
import numpy as np
import pandas as pd
from PIL import Image, ImageDraw
from anndata import AnnData
import tifffile
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import scipy.io
import math
from tqdm import tqdm
from skimage.measure import label, regionprops
from scipy.sparse import issparse
import matplotlib as mpl
from skimage import morphology
from cellpose import core, utils, io, models, metrics, plot
from cellpose.io import logger_setup 
import read_roi
import matplotlib.patches as patches
import matplotlib.path as mpath
import time
import os
import pickle
from scipy.ndimage import center_of_mass
import glob
# Out:
# C:\Users\Duan Lab\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import sys
sys.path.append("G:/LZ/pyScMERFISH")

# %%
# import pyScMERFISH_v4 not working yet
# if any function modified while in the middle of this notebook, kernel need to be restarted to enable those changes

# %%
import pyScMERFISH_v3_8

# %%
sample_name="pan697m13"
filepath="E:/RUN_temp/PAN/PAN_WGA_697M13/"
quantile=0.95
window_size = 2000
modeldir= "G:/LZ/MERFISH_CL008WT/cellpose_model/CL_MERFISH_v4"
diameter=80
cell_number=50

adatafilepath = "E:/RUN_temp/PAN/PAN_WGA_697M13/anndata_folder/"
#outputadatafilepath="E:/RUN_temp/PAN/202304071426_PanWGA4-P4-slide3_VMSC01801/anndata_processed_folder/"

# %%
regionames = ["region_4"]

# %%
# Cell segmentation and generate anndata
# ROI selection
for region_name in regionames:
    
    inputfilepath=filepath+region_name+"/"
    dapipath=inputfilepath
    outputfilepath=inputfilepath
   # ROI_coordinate=ROIcoordinates[regionames.index(region_name)]
    
    pyScMERFISH_v3_8.MIP(inputfilepath=inputfilepath,sample_name=sample_name,region_name=region_name)
    
    print("transform micron to pixel and reformat Spots in ROI for",region_name)
    pyScMERFISH_v3_8.Spots(dapipath=dapipath,inputfilepath=inputfilepath,quantile=quantile,outputfilepath=outputfilepath,sample_name=sample_name,region_name=region_name)
 
    # Use ClusterMap to split data into small tiles
    pyScMERFISH_v3_8.Tile_Filter_Split_ClusterMap(inputfilepath=inputfilepath,sample_name=sample_name,region_name=region_name,tilenum=50,outputfilepath=outputfilepath,window_size=window_size)

    # Cell segmentation by Cellpose
    # CPU 20 min per sample
    pyScMERFISH_v3_8.Segmentation_by_Cellpose(inputfilepath=inputfilepath,sample_name=sample_name,region_name=region_name,window_size=window_size,modeldir=modeldir,diameter=80,outputfilepath=outputfilepath)

    pyScMERFISH_v3_8.Reshape_RemovalEdgeCell(inputfilepath=inputfilepath,window_size=window_size)

    # stitch filtered_tiles back to cell masks and genrate anndata
    reassigned_masks = pyScMERFISH_v3_8.Reassign_Mask_Plotting_woROI(inputfilepath=inputfilepath,window_size=window_size,sample_name=sample_name,region_name=region_name)

    adata = pyScMERFISH_v3_8.ClusterMap_model_and_Anndata(inputfilepath=inputfilepath,adatafilepath=adatafilepath,cell_number=cell_number,sample_name=sample_name,region_name=region_name,gene_1="Slc17a6",gene_2="Gad1",addmWmC=True)

    pyScMERFISH_v3_8.plot_cell(inputfilepath=inputfilepath,cell_ID_in_reassigned_masks=adata.obs.shape[0]-100,gene1="Slc17a6",gene2="Gad1")
# 1475092    93.401291  1373.272949  192      Syt4  ENSMUST00000025110
# 1475093    97.741753  1043.783569  192  Blank-13                  -1
# 1475094    95.935555  1043.419922  192  Blank-13                  -1
# 1475095   103.237251  1376.554077  192  Blank-13                  -1
#
#          spot_location_1  spot_location_2
# 0                   1764              838
# 1                   1103             1146
# 2                    427              604
# 3                   1420             1758
# 4                   1614             1612
# ...                  ...              ...
# 1475091            31992            23728
# 1475092            31988            23788
# 1475093            31992            23458
# 1475094            31990            23458
# 1475095            31998            23791
#
# [1475096 rows x 12 columns]
# adapt data format to ClusterMap
# sort the gene name from A-Z, 0-314, e.g. 0 is Abtb2
# add 1 to gene ID from A-Z, 1-315, e.g. 1 is Abtb2
# concise table for transcripts (spots)
#         gene_name  spot_location_1  spot_location_2  gene
# 0          Tfap2b             1764              838   169
# 1         Col25a1             1103             1146    63
# 2           Cbln2              427              604    53
# 3           Cbln2             1420             1758    53
# 4          Nap1l5             1614             1612   116
# ...           ...              ...              ...   ...
# 1475091      Syt4            31992            23728   164
# 1475092      Syt4            31988            23788   164
# 1475093  Blank-13            31992            23458    12
# 1475094  Blank-13            31990            23458    12
# 1475095  Blank-13            31998            23791    12
#
# [1475096 rows x 4 columns]
# the format is compatible with ClusterMap now
# Overall Progress:   0%|                                                                          | 0/2 [00:00<?, ?it/s]
# E:/RUN_temp/PAN/PAN_WGA_697M13/region_4/pan697m13_region_4_dapi_in_ROI_MIP.tif
# Overall Progress: 100%|██████████████████████████████████████████████████████████████████| 2/2 [02:25<00:00, 72.84s/it]
# Split finished: 340 tiles
# the number of tiles with 3000+ spots is 97
# their ID are: [2, 3, 4, 5, 6, 7, 18, 19, 20, 21, 22, 23, 24, 25, 26, 35, 36, 37, 38, 39, 40, 41, 42, 43, 52, 53, 54, 55, 56, 57, 58, 59, 60, 70, 71, 72, 73, 74, 75, 76, 77, 88, 89, 90, 91, 92, 93, 94, 107, 108, 109, 110, 182, 183, 195, 196, 197, 198, 199, 200, 201, 202, 212, 213, 214, 215, 216, 217, 218, 219, 229, 230, 231, 232, 233, 234, 235, 236, 247, 248, 249, 250, 251, 252, 253, 264, 265, 266, 267, 268, 269, 270, 283, 284, 285, 286, 287]
# now display the location of the total 97 filtered tiles out of total 340 splitted tiles
# now saving the tile as: 2.png
# now saving the tile as: 3.png
# now saving the tile as: 4.png
# now saving the tile as: 5.png
# now saving the tile as: 6.png
# now saving the tile as: 7.png
# now saving the tile as: 18.png
# now saving the tile as: 19.png
# now saving the tile as: 20.png
# now saving the tile as: 21.png
# now saving the tile as: 22.png
# now saving the tile as: 23.png
# now saving the tile as: 24.png
# now saving the tile as: 25.png
# now saving the tile as: 26.png
# now saving the tile as: 35.png
# now saving the tile as: 36.png
# now saving the tile as: 37.png
# now saving the tile as: 38.png
# now saving the tile as: 39.png
# now saving the tile as: 40.png
# now saving the tile as: 41.png
# now saving the tile as: 42.png
# now saving the tile as: 43.png
# now saving the tile as: 52.png
# now saving the tile as: 53.png
# now saving the tile as: 54.png
# now saving the tile as: 55.png
# now saving the tile as: 56.png
# now saving the tile as: 57.png
# now saving the tile as: 58.png
# now saving the tile as: 59.png
# now saving the tile as: 60.png
# now saving the tile as: 70.png
# now saving the tile as: 71.png
# now saving the tile as: 72.png
# now saving the tile as: 73.png
# now saving the tile as: 74.png
# now saving the tile as: 75.png
# now saving the tile as: 76.png
# now saving the tile as: 77.png
# now saving the tile as: 88.png
# now saving the tile as: 89.png
# now saving the tile as: 90.png
# now saving the tile as: 91.png
# now saving the tile as: 92.png
# now saving the tile as: 93.png
# now saving the tile as: 94.png
# now saving the tile as: 107.png
# now saving the tile as: 108.png
# now saving the tile as: 109.png
# now saving the tile as: 110.png
# now saving the tile as: 182.png
# now saving the tile as: 183.png
# now saving the tile as: 195.png
# now saving the tile as: 196.png
# now saving the tile as: 197.png
# now saving the tile as: 198.png
# now saving the tile as: 199.png
# now saving the tile as: 200.png
# now saving the tile as: 201.png
# now saving the tile as: 202.png
# now saving the tile as: 212.png
# now saving the tile as: 213.png
# now saving the tile as: 214.png
# now saving the tile as: 215.png
# now saving the tile as: 216.png
# now saving the tile as: 217.png
# now saving the tile as: 218.png
# now saving the tile as: 219.png
# now saving the tile as: 229.png
# now saving the tile as: 230.png
# now saving the tile as: 231.png
# now saving the tile as: 232.png
# now saving the tile as: 233.png
# now saving the tile as: 234.png
# now saving the tile as: 235.png
# now saving the tile as: 236.png
# now saving the tile as: 247.png
# now saving the tile as: 248.png
# now saving the tile as: 249.png
# now saving the tile as: 250.png
# now saving the tile as: 251.png
# now saving the tile as: 252.png
# now saving the tile as: 253.png
# now saving the tile as: 264.png
# now saving the tile as: 265.png
# now saving the tile as: 266.png
# now saving the tile as: 267.png
# now saving the tile as: 268.png
# now saving the tile as: 269.png
# now saving the tile as: 270.png
# now saving the tile as: 283.png
# now saving the tile as: 284.png
# now saving the tile as: 285.png
# now saving the tile as: 286.png
# now saving the tile as: 287.png
# creating new log file
# 2025-02-03 11:30:55,832 [INFO] WRITING LOG OUTPUT TO C:\Users\Duan Lab\.cellpose\run.log
# 2025-02-03 11:30:55,833 [INFO]
# cellpose version: 	2.2.3
# platform:       	win32
# python version: 	3.11.5
# torch version:  	2.2.0+cu121
# 2025-02-03 11:31:22,473 [INFO] >>>> loading model G:/LZ/MERFISH_CL008WT/cellpose_model/CL_MERFISH_v4
# 2025-02-03 11:31:22,958 [INFO] ** TORCH CUDA version installed and working. **
# 2025-02-03 11:31:22,959 [INFO] >>>> using GPU
# 2025-02-03 11:31:23,198 [INFO] >>>> model diam_mean =  30.000 (ROIs rescaled to this size during training)
# 2025-02-03 11:31:23,200 [INFO] >>>> model diam_labels =  65.200 (mean diameter of training ROIs)
# Cellpose segmentation and saving npy files
# 2025-02-03 11:31:23,201 [INFO] 0%|          | 0/97 [00:00<?, ?it/s]
# 2025-02-03 11:31:27,509 [INFO] 1%|1         | 1/97 [00:04<06:53,  4.31s/it]
# 2025-02-03 11:31:29,279 [INFO] 2%|2         | 2/97 [00:06<04:27,  2.81s/it]
# 2025-02-03 11:34:07,383 [INFO] 91%|######### | 88/97 [02:44<00:16,  1.87s/it]
# 2025-02-03 11:34:09,259 [INFO] 92%|#########1| 89/97 [02:46<00:14,  1.87s/it]
# 2025-02-03 11:34:11,222 [INFO] 93%|#########2| 90/97 [02:48<00:13,  1.90s/it]
# 2025-02-03 11:34:13,198 [INFO] 94%|#########3| 91/97 [02:49<00:11,  1.92s/it]
# 2025-02-03 11:34:14,988 [INFO] 95%|#########4| 92/97 [02:51<00:09,  1.88s/it]
# 2025-02-03 11:34:16,705 [INFO] 96%|#########5| 93/97 [02:53<00:07,  1.83s/it]
# 2025-02-03 11:34:18,556 [INFO] 97%|#########6| 94/97 [02:55<00:05,  1.84s/it]
# 2025-02-03 11:34:20,560 [INFO] 98%|#########7| 95/97 [02:57<00:03,  1.89s/it]
# 2025-02-03 11:34:22,372 [INFO] 99%|#########8| 96/97 [02:59<00:01,  1.87s/it]
# 2025-02-03 11:34:24,024 [INFO] 100%|##########| 97/97 [03:00<00:00,  1.80s/it]
# 2025-02-03 11:34:24,025 [INFO] 100%|##########| 97/97 [03:00<00:00,  1.86s/it]
# now saving reshaped tile ID:  2 _reshaped.npy
# now saving reshaped tile ID:  3 _reshaped.npy
# now saving reshaped tile ID:  4 _reshaped.npy
# now saving reshaped tile ID:  5 _reshaped.npy
# now saving reshaped tile ID:  6 _reshaped.npy
# now saving reshaped tile ID:  7 _reshaped.npy
# now saving reshaped tile ID:  18 _reshaped.npy
# now saving reshaped tile ID:  19 _reshaped.npy
# now saving reshaped tile ID:  20 _reshaped.npy
# now saving reshaped tile ID:  21 _reshaped.npy
# now saving reshaped tile ID:  22 _reshaped.npy
# now saving reshaped tile ID:  23 _reshaped.npy
# now saving reshaped tile ID:  24 _reshaped.npy
# now saving reshaped tile ID:  25 _reshaped.npy
# now saving reshaped tile ID:  26 _reshaped.npy
# now saving reshaped tile ID:  35 _reshaped.npy
# now saving reshaped tile ID:  36 _reshaped.npy
# now saving reshaped tile ID:  37 _reshaped.npy
# now saving reshaped tile ID:  38 _reshaped.npy
# now saving reshaped tile ID:  39 _reshaped.npy
# now saving reshaped tile ID:  40 _reshaped.npy
# now saving reshaped tile ID:  41 _reshaped.npy
# now saving reshaped tile ID:  42 _reshaped.npy
# now saving reshaped tile ID:  43 _reshaped.npy
# now saving reshaped tile ID:  52 _reshaped.npy
# now saving reshaped tile ID:  53 _reshaped.npy
# now saving reshaped tile ID:  54 _reshaped.npy
# now saving reshaped tile ID:  55 _reshaped.npy
# now saving reshaped tile ID:  56 _reshaped.npy
# now saving reshaped tile ID:  57 _reshaped.npy
# now saving reshaped tile ID:  58 _reshaped.npy
# now saving reshaped tile ID:  59 _reshaped.npy
# now saving reshaped tile ID:  60 _reshaped.npy
# now saving reshaped tile ID:  70 _reshaped.npy
# now saving reshaped tile ID:  71 _reshaped.npy
# now saving reshaped tile ID:  72 _reshaped.npy
# now saving reshaped tile ID:  73 _reshaped.npy
# now saving reshaped tile ID:  74 _reshaped.npy
# now saving reshaped tile ID:  75 _reshaped.npy
# now saving reshaped tile ID:  76 _reshaped.npy
# now saving reshaped tile ID:  77 _reshaped.npy
# now saving reshaped tile ID:  88 _reshaped.npy
# now saving reshaped tile ID:  89 _reshaped.npy
# now saving reshaped tile ID:  90 _reshaped.npy
# now saving reshaped tile ID:  91 _reshaped.npy
# now saving reshaped tile ID:  92 _reshaped.npy
# now saving reshaped tile ID:  93 _reshaped.npy
# now saving reshaped tile ID:  94 _reshaped.npy
# now saving reshaped tile ID:  107 _reshaped.npy
# now saving reshaped tile ID:  108 _reshaped.npy
# now saving reshaped tile ID:  109 _reshaped.npy
# now saving reshaped tile ID:  110 _reshaped.npy
# now saving reshaped tile ID:  182 _reshaped.npy
# now saving reshaped tile ID:  183 _reshaped.npy
# now saving reshaped tile ID:  195 _reshaped.npy
# now saving reshaped tile ID:  196 _reshaped.npy
# now saving reshaped tile ID:  197 _reshaped.npy
# now saving reshaped tile ID:  198 _reshaped.npy
# now saving reshaped tile ID:  199 _reshaped.npy
# now saving reshaped tile ID:  200 _reshaped.npy
# now saving reshaped tile ID:  201 _reshaped.npy
# now saving reshaped tile ID:  202 _reshaped.npy
# now saving reshaped tile ID:  212 _reshaped.npy
# now saving reshaped tile ID:  213 _reshaped.npy
# now saving reshaped tile ID:  214 _reshaped.npy
# now saving reshaped tile ID:  215 _reshaped.npy
# now saving reshaped tile ID:  216 _reshaped.npy
# now saving reshaped tile ID:  217 _reshaped.npy
# now saving reshaped tile ID:  218 _reshaped.npy
# now saving reshaped tile ID:  219 _reshaped.npy
# now saving reshaped tile ID:  229 _reshaped.npy
# now saving reshaped tile ID:  230 _reshaped.npy
# now saving reshaped tile ID:  231 _reshaped.npy
# now saving reshaped tile ID:  232 _reshaped.npy
# now saving reshaped tile ID:  233 _reshaped.npy
# now saving reshaped tile ID:  234 _reshaped.npy
# now saving reshaped tile ID:  235 _reshaped.npy
# now saving reshaped tile ID:  236 _reshaped.npy
# now saving reshaped tile ID:  247 _reshaped.npy
# now saving reshaped tile ID:  248 _reshaped.npy
# now saving reshaped tile ID:  249 _reshaped.npy
# now saving reshaped tile ID:  250 _reshaped.npy
# now saving reshaped tile ID:  251 _reshaped.npy
# now saving reshaped tile ID:  252 _reshaped.npy
# now saving reshaped tile ID:  253 _reshaped.npy
# now saving reshaped tile ID:  264 _reshaped.npy
# now saving reshaped tile ID:  265 _reshaped.npy
# now saving reshaped tile ID:  266 _reshaped.npy
# now saving reshaped tile ID:  267 _reshaped.npy
# now saving reshaped tile ID:  268 _reshaped.npy
# now saving reshaped tile ID:  269 _reshaped.npy
# now saving reshaped tile ID:  270 _reshaped.npy
# now saving reshaped tile ID:  283 _reshaped.npy
# now saving reshaped tile ID:  284 _reshaped.npy
# now saving reshaped tile ID:  285 _reshaped.npy
# now saving reshaped tile ID:  286 _reshaped.npy
# now saving reshaped tile ID:  287 _reshaped.npy
# now saving reshaped_edge_cells_removal tile ID:  2 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  3 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  4 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  5 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  6 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  7 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  18 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  19 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  20 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  21 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  22 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  23 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  24 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  25 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  26 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  35 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  36 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  37 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  38 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  39 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  40 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  41 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  42 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  43 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  52 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  53 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  54 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  55 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  56 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  57 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  58 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  59 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  60 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  70 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  71 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  72 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  73 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  74 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  75 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  76 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  77 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  88 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  89 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  90 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  91 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  92 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  93 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  94 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  107 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  108 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  109 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  110 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  182 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  183 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  195 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  196 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  197 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  198 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  199 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  200 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  201 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  202 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  212 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  213 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  214 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  215 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  216 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  217 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  218 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  219 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  229 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  230 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  231 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  232 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  233 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  234 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  235 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  236 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  247 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  248 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  249 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  250 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  251 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  252 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  253 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  264 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  265 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  266 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  267 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  268 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  269 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  270 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  283 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  284 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  285 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  286 _reshaped_edge_cells_removal.npy
# now saving reshaped_edge_cells_removal tile ID:  287 _reshaped_edge_cells_removal.npy
# now is processing filtered tile # 2
# now stitched another 12 cells
# now the total combined_tile cell mask numbers now is 12
# Now total 1 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 3
# now stitched another 24 cells
# now the total combined_tile cell mask numbers now is 29
# Now total 2 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 4
# now stitched another 22 cells
# now the total combined_tile cell mask numbers now is 26
# Now total 3 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 5
# now stitched another 53 cells
# now the total combined_tile cell mask numbers now is 56
# Now total 4 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 6
# now stitched another 40 cells
# now the total combined_tile cell mask numbers now is 54
# Now total 5 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 7
# now stitched another 18 cells
# now the total combined_tile cell mask numbers now is 24
# Now total 6 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 18
# now stitched another 3 cells
# now the total combined_tile cell mask numbers now is 3
# Now total 7 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 19
# now stitched another 32 cells
# now the total combined_tile cell mask numbers now is 37
# Now total 8 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 20
# now stitched another 23 cells
# now the total combined_tile cell mask numbers now is 35
# Now total 9 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 21
# now stitched another 18 cells
# now the total combined_tile cell mask numbers now is 31
# Now total 10 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 22
# now stitched another 29 cells
# now the total combined_tile cell mask numbers now is 48
# Now total 11 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 23
# now stitched another 50 cells
# now the total combined_tile cell mask numbers now is 69
# Now total 12 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 24
# now stitched another 63 cells
# now the total combined_tile cell mask numbers now is 83
# Now total 13 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 25
# now stitched another 51 cells
# now the total combined_tile cell mask numbers now is 67
# Now total 14 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 26
# now stitched another 10 cells
# now the total combined_tile cell mask numbers now is 14
# Now total 15 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 35
# now stitched another 1 cells
# now the total combined_tile cell mask numbers now is 4
# Now total 16 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 36
# now stitched another 53 cells
# now the total combined_tile cell mask numbers now is 62
# Now total 17 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 37
# now stitched another 55 cells
# now the total combined_tile cell mask numbers now is 70
# Now total 18 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 38
# now stitched another 30 cells
# now the total combined_tile cell mask numbers now is 41
# Now total 19 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 39
# now stitched another 49 cells
# now the total combined_tile cell mask numbers now is 65
# Now total 20 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 40
# now stitched another 35 cells
# now the total combined_tile cell mask numbers now is 50
# Now total 21 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 41
# now stitched another 54 cells
# now the total combined_tile cell mask numbers now is 82
# Now total 22 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 42
# now stitched another 57 cells
# now the total combined_tile cell mask numbers now is 90
# Now total 23 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 43
# now stitched another 22 cells
# now the total combined_tile cell mask numbers now is 32
# Now total 24 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 52
# now stitched another 19 cells
# now the total combined_tile cell mask numbers now is 19
# Now total 25 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 53
# now stitched another 83 cells
# now the total combined_tile cell mask numbers now is 102
# Now total 26 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 54
# now stitched another 66 cells
# now the total combined_tile cell mask numbers now is 93
# Now total 27 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 55
# now stitched another 55 cells
# now the total combined_tile cell mask numbers now is 79
# Now total 28 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 56
# now stitched another 64 cells
# now the total combined_tile cell mask numbers now is 83
# Now total 29 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 57
# now stitched another 44 cells
# now the total combined_tile cell mask numbers now is 62
# Now total 30 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 58
# now stitched another 46 cells
# now the total combined_tile cell mask numbers now is 67
# Now total 31 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 59
# now stitched another 52 cells
# now the total combined_tile cell mask numbers now is 75
# Now total 32 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 60
# now stitched another 27 cells
# now the total combined_tile cell mask numbers now is 41
# Now total 33 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 70
# now stitched another 40 cells
# now the total combined_tile cell mask numbers now is 65
# Now total 34 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 71
# now stitched another 72 cells
# now the total combined_tile cell mask numbers now is 100
# Now total 35 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 72
# now stitched another 90 cells
# now the total combined_tile cell mask numbers now is 120
# Now total 36 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 73
# now stitched another 78 cells
# now the total combined_tile cell mask numbers now is 109
# Now total 37 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 74
# now stitched another 60 cells
# now the total combined_tile cell mask numbers now is 87
# Now total 38 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 75
# now stitched another 68 cells
# now the total combined_tile cell mask numbers now is 91
# Now total 39 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 76
# now stitched another 66 cells
# now the total combined_tile cell mask numbers now is 91
# Now total 40 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 77
# now stitched another 29 cells
# now the total combined_tile cell mask numbers now is 47
# Now total 41 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 88
# now stitched another 8 cells
# now the total combined_tile cell mask numbers now is 16
# Now total 42 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 89
# now stitched another 27 cells
# now the total combined_tile cell mask numbers now is 60
# Now total 43 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 90
# now stitched another 39 cells
# now the total combined_tile cell mask numbers now is 65
# Now total 44 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 91
# now stitched another 85 cells
# now the total combined_tile cell mask numbers now is 111
# Now total 45 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 92
# now stitched another 75 cells
# now the total combined_tile cell mask numbers now is 102
# Now total 46 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 93
# now stitched another 65 cells
# now the total combined_tile cell mask numbers now is 88
# Now total 47 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 94
# now stitched another 28 cells
# now the total combined_tile cell mask numbers now is 42
# Now total 48 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 107
# now stitched another 4 cells
# now the total combined_tile cell mask numbers now is 9
# Now total 49 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 108
# now stitched another 19 cells
# now the total combined_tile cell mask numbers now is 33
# Now total 50 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 109
# now stitched another 28 cells
# now the total combined_tile cell mask numbers now is 48
# Now total 51 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 110
# now stitched another 12 cells
# now the total combined_tile cell mask numbers now is 31
# Now total 52 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 182
# now stitched another 30 cells
# now the total combined_tile cell mask numbers now is 30
# Now total 53 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 183
# now stitched another 18 cells
# now the total combined_tile cell mask numbers now is 24
# Now total 54 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 195
# now stitched another 56 cells
# now the total combined_tile cell mask numbers now is 56
# Now total 55 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 196
# now stitched another 49 cells
# now the total combined_tile cell mask numbers now is 63
# Now total 56 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 197
# now stitched another 32 cells
# now the total combined_tile cell mask numbers now is 38
# Now total 57 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 198
# now stitched another 25 cells
# now the total combined_tile cell mask numbers now is 33
# Now total 58 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 199
# now stitched another 39 cells
# now the total combined_tile cell mask numbers now is 63
# Now total 59 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 200
# now stitched another 56 cells
# now the total combined_tile cell mask numbers now is 84
# Now total 60 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 201
# now stitched another 37 cells
# now the total combined_tile cell mask numbers now is 50
# Now total 61 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 202
# now stitched another 13 cells
# now the total combined_tile cell mask numbers now is 19
# Now total 62 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 212
# now stitched another 62 cells
# now the total combined_tile cell mask numbers now is 85
# Now total 63 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 213
# now stitched another 63 cells
# now the total combined_tile cell mask numbers now is 87
# Now total 64 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 214
# now stitched another 28 cells
# now the total combined_tile cell mask numbers now is 54
# Now total 65 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 215
# now stitched another 36 cells
# now the total combined_tile cell mask numbers now is 50
# Now total 66 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 216
# now stitched another 37 cells
# now the total combined_tile cell mask numbers now is 52
# Now total 67 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 217
# now stitched another 45 cells
# now the total combined_tile cell mask numbers now is 72
# Now total 68 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 218
# now stitched another 66 cells
# now the total combined_tile cell mask numbers now is 85
# Now total 69 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 219
# now stitched another 47 cells
# now the total combined_tile cell mask numbers now is 67
# Now total 70 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 229
# now stitched another 31 cells
# now the total combined_tile cell mask numbers now is 42
# Now total 71 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 230
# now stitched another 85 cells
# now the total combined_tile cell mask numbers now is 116
# Now total 72 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 231
# now stitched another 45 cells
# now the total combined_tile cell mask numbers now is 70
# Now total 73 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 232
# now stitched another 42 cells
# now the total combined_tile cell mask numbers now is 55
# Now total 74 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 233
# now stitched another 45 cells
# now the total combined_tile cell mask numbers now is 66
# Now total 75 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 234
# now stitched another 48 cells
# now the total combined_tile cell mask numbers now is 64
# Now total 76 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 235
# now stitched another 45 cells
# now the total combined_tile cell mask numbers now is 73
# Now total 77 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 236
# now stitched another 55 cells
# now the total combined_tile cell mask numbers now is 81
# Now total 78 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 247
# now stitched another 52 cells
# now the total combined_tile cell mask numbers now is 74
# Now total 79 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 248
# now stitched another 88 cells
# now the total combined_tile cell mask numbers now is 116
# Now total 80 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 249
# now stitched another 61 cells
# now the total combined_tile cell mask numbers now is 91
# Now total 81 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 250
# now stitched another 61 cells
# now the total combined_tile cell mask numbers now is 84
# Now total 82 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 251
# now stitched another 72 cells
# now the total combined_tile cell mask numbers now is 98
# Now total 83 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 252
# now stitched another 58 cells
# now the total combined_tile cell mask numbers now is 82
# Now total 84 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 253
# now stitched another 41 cells
# now the total combined_tile cell mask numbers now is 65
# Now total 85 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 264
# now stitched another 3 cells
# now the total combined_tile cell mask numbers now is 10
# Now total 86 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 265
# now stitched another 39 cells
# now the total combined_tile cell mask numbers now is 67
# Now total 87 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 266
# now stitched another 72 cells
# now the total combined_tile cell mask numbers now is 101
# Now total 88 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 267
# now stitched another 64 cells
# now the total combined_tile cell mask numbers now is 96
# Now total 89 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 268
# now stitched another 78 cells
# now the total combined_tile cell mask numbers now is 110
# Now total 90 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile # 269
# now stitched another 86 cells
# now the total combined_tile cell mask numbers now is 120
# Now total 91 out of 97 filtered tiles got stitched.
# ----------
# now is processing filtered tile #
ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   ClusterMap_model.cell_adata.obs['mWmC'] = ClusterMap_model.cell_adata.obs.index.isin(str_list).astype(str)
# cell ID in reassigned_masks_new:  1316
#
# Centroid coordinates (shown as yellow dot) of this cell in DAPI scale:  (10661, 8378)
# Centroid coordinates (shown as yellow dot) of this cell in Dots scale in Visualizer:  (1116.4814929518366, 2265.856987440726)
#
# Volume of this cell:  [6981.0]
#
# Total counts of this cell (white dots):  120
# 1 counts of blank genes
# Slc17a6 counts of this cell (green dots):  1
# Gad1 counts of this cell (green dots):  0
# ... storing 'mWmC' as categorical
# cell ID in reassigned_masks_new:  4166
#
# Centroid coordinates (shown as yellow dot) of this cell in DAPI scale:  (23354, 32480)
# Centroid coordinates (shown as yellow dot) of this cell in Dots scale in Visualizer:  (2487.2729765529493, 4868.775947924274)
#
# Volume of this cell:  [6088.0]
#
# Total counts of this cell (white dots):  110
# 1 counts of blank genes
# Slc17a6 counts of this cell (green dots):  2
# Gad1 counts of this cell (green dots):  5

# %%
cytointensf = []
gap = int(window_size*0.1)
for k in range(0,7):
   print(k)
   img=tifffile.imread(inputfilepath+'images/mosaic_'+mWmC_channelName+'_z'+str(k)+'.tif')

   cytointensf_t =[]        
   cytointensf_t =getinten(img, cytomask)
   cytointensf.append(cytointensf_t)

cytointenmean=np.mean(np.array(cytointensf),axis=0)
cytointenmax=np.max(np.array(cytointensf),axis=0)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
cytointenmean
# Out:
# array([], dtype=float64)

# %%
print("calculated the intensity (cyto masking) of ",len(cytointenmax)," cells in ",sample_name,region_name)

from skimage.filters import threshold_otsu

cytohistogram, bin_edges= np.histogram(cytointenmax,500)
cytoThreshold_max= bin_edges[threshold_otsu(image=None, nbins=500, hist=(cytohistogram))]

cytointenmax1=cytointenmax[cytointenmax>cytoThreshold_max]
histogram1, bin_edges= np.histogram(cytointenmax1,500)
cytoThreshold_max1= bin_edges[threshold_otsu(image=None, nbins=500, hist=(histogram1))]

plt.hist(cytointenmax,500)
plt.plot([cytoThreshold_max1,cytoThreshold_max1],[max(cytohistogram), 0])
plt.savefig(inputfilepath + "otsu_thresholding_cytomask.png")
plt.savefig(inputfilepath + "otsu_thresholding_cytomask.pdf")
plt.show()

# use normal masking
intensf = []
masks =[]
gap = int(window_size*0.1)
masks = new_masks[gap:new_masks.shape[0]-gap, gap:new_masks.shape[1]-gap]
for k in range(0,7):
   print(k)
   img=tifffile.imread(inputfilepath+'images/mosaic_'+mWmC_channelName+'_z'+str(k)+'.tif')
   intensf_t =[]        
   intensf_t =getinten(img, masks)
   intensf.append(intensf_t)

intenmean=np.mean(np.array(intensf),axis=0)
intenmax=np.max(np.array(intensf),axis=0)

print("calculated the intensity (normal masking) of ",len(cytointenmax)," cells in ",sample_name,region_name)

from skimage.filters import threshold_otsu
histogram, bin_edges= np.histogram(intenmax,500)
Threshold_max= bin_edges[threshold_otsu(image=None, nbins=500, hist=(histogram))]
intenmax1=intenmax[intenmax>Threshold_max]
histogram1, bin_edges= np.histogram(intenmax1,500)
Threshold_max1= bin_edges[threshold_otsu(image=None, nbins=500, hist=(histogram1))]

plt.hist(intenmax,500)
plt.plot([Threshold_max1,Threshold_max1],[max(histogram), 0])
plt.savefig(inputfilepath + "otsu_thresholding_normalmask.png")
plt.savefig(inputfilepath + "otsu_thresholding_normalmask.pdf")

cell_with_transcripts = ClusterMap_model.spots['clustermap'].unique()[1:]
ClusterMap_model.cell_adata.obs['Intens_mean'] =  cytointenmean[cell_with_transcripts]
ClusterMap_model.cell_adata.obs['Intens_max'] =intenmax[cell_with_transcripts]
ClusterMap_model.cell_adata.obs['Intens_max_cyto'] =cytointenmax[cell_with_transcripts]
ClusterMap_model.cell_adata.obs['Size'] = np.array(areas)[cell_with_transcripts]
ClusterMap_model.cell_adata.obs['Labeled']= (ClusterMap_model.cell_adata.obs['Intens_max']>Threshold_max1)*1

adata = ClusterMap_model.cell_adata
adata.var.index.name = 'genes'
adata.write_h5ad(inputfilepath+"adata_in_SCROI_"+sample_name+"_"+region_name+".h5ad")
adata.write_h5ad(adatafilepath+"adata_in_SCROI_"+sample_name+"_"+region_name+".h5ad")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
# Cell segmentation and generate anndata
# ROI selection
for region_name in regionames:
    
    inputfilepath=filepath+region_name+"/"
    dapipath=inputfilepath
    outputfilepath=inputfilepath
    ROI_coordinate=ROIcoordinates[regionames.index(region_name)]
    
    #print("transform micron to pixel and reformat Spots in ROI for",region_name)
    #pyScMERFISH_v4.Spots_in_ROI(dapipath=dapipath,inputfilepath=inputfilepath,quantile=quantile,outputfilepath=outputfilepath,ROI_coordinate=ROI_coordinate,sample_name=sample_name,region_name=region_name)
 
    # Use ClusterMap to split data into small tiles
    #pyScMERFISH_v4.Tile_Filter_Split_ClusterMap(inputfilepath=inputfilepath,sample_name=sample_name,region_name=region_name,tilenum=50,outputfilepath=outputfilepath,window_size=window_size)

    # Cell segmentation by Cellpose
    # CPU 20 min per sample
    #pyScMERFISH_v4.Segmentation_by_Cellpose(inputfilepath=inputfilepath,sample_name=sample_name,region_name=region_name,window_size=window_size,modeldir=modeldir,diameter=80,ROI_coordinate=ROI_coordinate,outputfilepath=outputfilepath)

    #pyScMERFISH_v4.Reshape_RemovalEdgeCell(inputfilepath=inputfilepath,window_size=window_size)

    # stitch filtered_tiles back to cell masks and genrate anndata
    #reassigned_masks = pyScMERFISH_v4.Reassign_Mask_Plotting(inputfilepath=inputfilepath,window_size=window_size,sample_name=sample_name,region_name=region_name,ROI_coordinate=ROI_coordinate)

    adata = pyScMERFISH_v4.ClusterMap_model_and_Anndata(inputfilepath=inputfilepath,adatafilepath=adatafilepath,cell_number=cell_number,sample_name=sample_name,region_name=region_name,gene_1="Slc17a6",gene_2="Gad1",addmWmC=True,addIntenmWmC=True,mWmC_channelName="Cellbound3")

    pyScMERFISH_v4.plot_cell(inputfilepath=inputfilepath,cell_ID_in_reassigned_masks=adata.obs.shape[0]-100,gene1="Slc17a6",gene2="Gad1")
# Out:
# spots_in_ROI
#         gene_name  spot_location_1  spot_location_2  gene
# 0           Ntng1             3275             5426   122
# 1           Ntng1             3195             5526   122
# 2           Ntng1             3797             5468   122
# 3           Ntng1             3764             5331   122
# 4           Ntng1             3750             5393   122
# ...           ...              ...              ...   ...
# 1853732  Blank-39            22138            11614    40
# 1853733  Blank-39            20819            11630    40
# 1853734  Blank-39            21011            11879    40
# 1853735  Blank-39            20799            12149    40
# 1853736  Blank-39            21505            11406    40
#
# [1853737 rows x 4 columns]
# spots_in_ROI after adding clustermap ID
# 3309 is the unique cell numbers with counts from reassigned_masks
# max cell ID from clustermap
# C:\Users\Duan Lab\anaconda3\Lib\site-packages\anndata\_core\anndata.py:183: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# 0
# 1
# 2
# 3
# 4
# 5
# 6
# calculated the intensity (cyto masking) of  0  cells in  cart676I2 region_2
# C:\Users\Duan Lab\anaconda3\Lib\site-packages\skimage\filters\thresholding.py:370: RuntimeWarning: invalid value encountered in divide
#   mean1 = np.cumsum(counts * bin_centers) / weight1
# C:\Users\Duan Lab\anaconda3\Lib\site-packages\skimage\filters\thresholding.py:371: RuntimeWarning: invalid value encountered in divide
#   mean2 = (np.cumsum((counts * bin_centers)[::-1]) / weight2[::-1])[::-1]
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# calculated the intensity (normal masking) of  0  cells in  cart676I2 region_2
# C:\Users\Duan Lab\anaconda3\Lib\site-packages\skimage\filters\thresholding.py:370: RuntimeWarning: invalid value encountered in divide
#   mean1 = np.cumsum(counts * bin_centers) / weight1
# C:\Users\Duan Lab\anaconda3\Lib\site-packages\skimage\filters\thresholding.py:371: RuntimeWarning: invalid value encountered in divide
#   mean2 = (np.cumsum((counts * bin_centers)[::-1]) / weight2[::-1])[::-1]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 25
#       8 ROI_coordinate=ROIcoordinates[regionames.index(region_name)]
#      10 #print("transform micron to pixel and reformat Spots in ROI for",region_name)
#      11 #pyScMERFISH_v4.Spots_in_ROI(dapipath=dapipath,inputfilepath=inputfilepath,quantile=quantile,outputfilepath=outputfilepath,ROI_coordinate=ROI_coordinate,sample_name=sample_name,region_name=region_name)
#      12
#    (...)
#      22 # stitch filtered_tiles back to cell masks and genrate anndata
#      23 #reassigned_masks = pyScMERFISH_v4.Reassign_Mask_Plotting(inputfilepath=inputfilepath,window_size=window_size,sample_name=sample_name,region_name=region_name,ROI_coordinate=ROI_coordinate)
# ---> 25 adata = pyScMERFISH_v4.ClusterMap_model_and_Anndata(inputfilepath=inputfilepath,adatafilepath=adatafilepath,cell_number=cell_number,sample_name=sample_name,region_name=region_name,gene_1="Slc17a6",gene_2="Gad1",addmWmC=True,addIntenmWmC=True,mWmC_channelName="Cellbound3")
#      27 pyScMERFISH_v4.plot_cell(inputfilepath=inputfilepath,cell_ID_in_reassigned_masks=adata.obs.shape[0]-100,gene1="Slc17a6",gene2="Gad1")
#
# File G:\LZ/pyScMERFISH\pyScMERFISH_v4.py:1037, in ClusterMap_model_and_Anndata(inputfilepath, adatafilepath, sample_name, region_name, cell_number, gene_1, gene_2, addmWmC, addIntenmWmC, mWmC_channelName)
#    1034 plt.savefig(inputfilepath + "otsu_thresholding_normalmask.pdf")
#    1036 cell_with_transcripts = ClusterMap_model.spots['clustermap'].unique()[1:]
# -> 1037 ClusterMap_model.cell_adata.obs['Intens_mean'] =  cytointenmean[cell_with_transcripts]
#    1038 ClusterMap_model.cell_adata.obs['Intens_max'] =intenmax[cell_with_transcripts]
#    1039 ClusterMap_model.cell_adata.obs['Intens_max_cyto'] =cytointenmax[cell_with_transcripts]
#
# IndexError: index 1983 is out of bounds for axis 0 with size 0

# %%
regionames = ["region_2"]
ROIcoordinates = ['06804-12816']
region_name="region_2"

# %%
inputfilepath=filepath+region_name+"/"
dapipath=inputfilepath
outputfilepath=inputfilepath
ROI_coordinate=ROIcoordinates[regionames.index(region_name)]

# %%
# %reset -f

import gc
gc.collect()
# Out:
# 0

# %%
# region 5 debug with pyScMERFISH_v3_8

# %%
# Debug ROI at edge
